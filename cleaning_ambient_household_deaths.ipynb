# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\MYPC\Downloads\datasets\ambient household deaths.csv")

# %%
df.T
# Out:
#                                                                         0      \
# IndicatorCode                                                      SDGAIRBODA
# Indicator                   Ambient and household air pollution attributab...
# ValueType                                                             numeric
# ParentLocationCode                                                        AMR
# ParentLocation                                                       Americas
# Location type                                                         Country
# SpatialDimValueCode                                                       ATG
# Location                                                  Antigua and Barbuda
# Period type                                                              Year
# Period                                                                   2019
# IsLatestYear                                                             True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32400 entries, 0 to 32399
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   IndicatorCode               32400 non-null  object
#  1   Indicator                   32400 non-null  object
#  2   ValueType                   32400 non-null  object
#  3   ParentLocationCode          32400 non-null  object
#  4   ParentLocation              32400 non-null  object
#  5   Location type               32400 non-null  object
#  6   SpatialDimValueCode         32400 non-null  object
#  7   Location                    32400 non-null  object
#  8   Period type                 32400 non-null  object
#  9   Period                      32400 non-null  int64
#  10  IsLatestYear                32400 non-null  bool
#  11  Dim1 type                   32400 non-null  object
#  12  Dim1                        32400 non-null  object
# ...

# %%
df.columns = df.columns.str.lower().str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32400 entries, 0 to 32399
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   indicatorcode               32400 non-null  object
#  1   indicator                   32400 non-null  object
#  2   valuetype                   32400 non-null  object
#  3   parentlocationcode          32400 non-null  object
#  4   parentlocation              32400 non-null  object
#  5   location type               32400 non-null  object
#  6   spatialdimvaluecode         32400 non-null  object
#  7   location                    32400 non-null  object
#  8   period type                 32400 non-null  object
#  9   period                      32400 non-null  int64
#  10  islatestyear                32400 non-null  bool
#  11  dim1 type                   32400 non-null  object
#  12  dim1                        32400 non-null  object
# ...

# %%
df = df.drop(columns = ['indicatorcode', 'valuetype', 'parentlocationcode', 'spatialdimvaluecode', 'period type', 'islatestyear', 'dim1valuecode', 'dim3 type', 'dim3', 'dim3valuecode', 'datasourcedimvaluecode', 'datasource', 'factvaluenumericprefix', 'factvalueuom', 'factvaluenumericlowprefix', 'factvaluenumerichighprefix', 'value', 'factvaluetranslationid', 'factcomments', 'language', 'datemodified'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32400 entries, 0 to 32399
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   indicator             32400 non-null  object
#  1   parentlocation        32400 non-null  object
#  2   location type         32400 non-null  object
#  3   location              32400 non-null  object
#  4   period                32400 non-null  int64
#  5   dim1 type             32400 non-null  object
#  6   dim1                  32400 non-null  object
#  7   dim2 type             32400 non-null  object
#  8   dim2                  32400 non-null  object
#  9   dim2valuecode         32400 non-null  object
#  10  factvaluenumeric      32400 non-null  float64
#  11  factvaluenumericlow   32400 non-null  float64
#  12  factvaluenumerichigh  32400 non-null  float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 3.2+ MB

# %%
df.head()
# Out:
#                                            indicator parentlocation  \
# 0  Ambient and household air pollution attributab...       Americas
# 1  Ambient and household air pollution attributab...       Americas
# 2  Ambient and household air pollution attributab...       Americas
# 3  Ambient and household air pollution attributab...       Americas
# 4  Ambient and household air pollution attributab...       Americas
#
#   location type             location  period dim1 type        dim1  \
# 0       Country  Antigua and Barbuda    2019       Sex  Both sexes
# 1       Country  Antigua and Barbuda    2019       Sex      Female
# 2       Country              Bahamas    2019       Sex  Both sexes
# 3       Country              Bahamas    2019       Sex      Female
# 4       Country              Bahamas    2019       Sex        Male
#
#                   dim2 type                             dim2  \
# 0  GHE cause of death codes  Trachea, bronchus, lung cancers
# ...

# %%
df['period'].unique()
# Out:
# array([2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe().T
# Out:
#                         count         mean        std     min      25%  \
# period                32400.0  2014.500000   2.872326  2010.0  2012.00
# factvaluenumeric      32400.0    37.607877  55.696171     0.0     3.12
# factvaluenumericlow   32400.0    27.825483  45.876458     0.0     1.51
# factvaluenumerichigh  32400.0    48.093617  66.269773     0.0     5.30
#
#                           50%        75%     max
# period                2014.50  2017.0000  2019.0
# factvaluenumeric        14.16    50.5525   430.6
# factvaluenumericlow      8.59    34.9600   363.8
# factvaluenumerichigh    20.28    66.0000   503.4

# %%
df.to_csv("cleaned_ambient_household_deaths.csv", index = False)
